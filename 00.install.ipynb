# %%
! pip install -r requirements.txt
# Out:
# ...
#   Using cached duckdb-1.3.2-cp312-cp312-win_amd64.whl.metadata (7.2 kB)
# ...
# Using cached duckdb-1.3.2-cp312-cp312-win_amd64.whl (11.4 MB)
# ...
